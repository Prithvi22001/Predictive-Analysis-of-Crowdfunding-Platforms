# %%
# Import Libraries
import numpy as np
import pandas as pd
import glob
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Load the dataset
df1 = pd.read_csv(r'/content/drive/My Drive/Predictive Analysis of Crowdfunding Platforms/7.General Dataset (Final)/General Dataset Cleaned 2.csv')
df1.head()
# Out:
#    backers_count  ...    scores
# 0            256  ...  1.554951
# 1              8  ... -0.143421
# 2             59  ...  0.232367
# 3              6  ...  0.909679
# 4            463  ...  9.094467
#
# [5 rows x 33 columns]

# %%
df1['country'].value_counts().to_dict()
# Out:
# {'AT': 355,
#  'AU': 4340,
#  'BE': 472,
#  'CA': 8281,
#  'CH': 492,
#  'DE': 2487,
#  'DK': 700,
#  'ES': 1458,
#  'FR': 1716,
#  'GB': 21633,
#  'HK': 1293,
#  'IE': 572,
#  'IT': 2043,
#  'JP': 419,
#  'LU': 46,
#  'MX': 704,
#  'NL': 1556,
#  'NO': 411,
#  'NZ': 833,
#  'SE': 1043,
#  'SG': 736,
#  'US': 126780}

# %%
df1.rename(columns = {'scores':'description_score'}, inplace = True) 
df1.head()
# Out:
#    backers_count  ... description_score
# 0            256  ...          1.554951
# 1              8  ...         -0.143421
# 2             59  ...          0.232367
# 3              6  ...          0.909679
# 4            463  ...          9.094467
#
# [5 rows x 33 columns]

# %%
# Load the dataset
df2 = pd.read_csv(r'/content/drive/My Drive/Predictive Analysis of Crowdfunding Platforms/5.NLP Metric Evaluation of General Dataset/Model/Description Prediction.csv')
df2.head()
# Out:
#    description_prediction
# 0                       1
# 1                       1
# 2                       1
# 3                       1
# 4                       1

# %%
df1.shape
# Out:
# (178370, 33)

# %%
df2.shape
# Out:
# (178370, 1)

# %%
df = pd.concat([df1, df2], axis=1)
df.head()
# Out:
#    backers_count  ... description_prediction
# 0            256  ...                      1
# 1              8  ...                      1
# 2             59  ...                      1
# 3              6  ...                      1
# 4            463  ...                      1
#
# [5 rows x 34 columns]

# %%
# Convert Dataframe to CSV File
df.to_csv("General Dataset Cleaned 3.csv", index=False)

# %%
df.shape
# Out:
# (178370, 34)
